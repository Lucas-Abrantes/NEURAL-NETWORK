# %%
import pandas as pd

# %%
df = pd.read_csv("export_customers_20240829_141121.csv")
df
# Out:
#             Last Name                  First Name Date of birth  \
# 0                 Leu                       Lucas    25.05.2024
# 1              Kaelin                       Lucas    19.09.1980
# 2   da Costa Salvador                  Joao Lucas    01.09.1998
# 3               Brent                       Lucas    16.12.1969
# 4               Brent                       Lucas    16.12.1969
# 5               Wendy                       Lucas    11.06.1974
# 6             Yannick  de almeida lucas fernandes    01.01.1970
# 7            Portelli                       Lucas    05.10.1981
# 8              Castro                       Lucas    29.08.1995
# 9         Schwaninger                       Lucas    26.09.2005
# 10             Ludwig                       Lucas           NaN
# 11           Climagel                 Lucas Weiss           NaN
# 12              Vugts                       Lucas           NaN
# 13         Maximilian                       Lucas           NaN
# ...

# %%
df['Saldo']
# Out:
# 01.01.2024    CHF 0,00
# 02.01.2024    CHF 0,00
# 03.01.2024    CHF 0,00
# 04.01.2024    CHF 0,00
# 05.01.2024    CHF 0,00
#                 ...
# 27.05.2024    CHF 0,00
# 28.05.2024    CHF 0,00
# 29.05.2024    CHF 0,00
# 30.05.2024    CHF 0,00
# Total              NaN
# Name: Saldo, Length: 152, dtype: object
